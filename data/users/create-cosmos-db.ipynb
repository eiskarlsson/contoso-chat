# %%
from azure.cosmos import CosmosClient, exceptions, PartitionKey
from azure.identity import DefaultAzureCredential
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential

# try:
#     credential = DefaultAzureCredential()
#     # Check if given credential can get token successfully.
#     credential.get_token("https://management.azure.com/.default")
# except Exception as ex:
#     # Fall back to InteractiveBrowserCredential in case DefaultAzureCredential not work
#     # This will open a browser page for
#     credential = InteractiveBrowserCredential()

# %%
# Set the Cosmos DB endpoint, key and database name in the .env file. The key and endpoint can be found in the resource created in the portal.
COSMOS_ENDPOINT = "https://limbodatingcosmosdbaccount.documents.azure.com:443/"
ACCOUNT_KEY="8VHVtfDrxyOuEiqzxoAk53FUZev6aB5JBilNZev8pxTc3Wg9ArUggj728qqcdlfiAgTh72ee560WACDbA5Bq6Q=="
# os.environ["COSMOS_ENDPOINT"]
client = CosmosClient(COSMOS_ENDPOINT, credential=ACCOUNT_KEY)
DATABASE_NAME = 'limbo-dating-database'
CONTAINER_NAME = 'users'

# %%
# Get the database and container created by Bicep
database = client.get_database_client(DATABASE_NAME)
container = database.get_container_client(CONTAINER_NAME)

print(database)
# Out:
# <DatabaseProxy [dbs/limbo-dating-database]>

# %%
# Loop through each json file in data/customer_info and insert into container
import os
import json
import glob
from azure.cosmos.exceptions import CosmosHttpResponseError

path = '.'
filename = glob.glob(os.path.join(path, 'users_info.json'))[0]
file = open(filename) 
users = json.load(file)
for user in users:
    try:
        container.upsert_item(user)
    except CosmosHttpResponseError as e:
        print(f"Error: {e}")
        print(f"Error Details: {e.message}")
    print('Upserted item with id {0}'.format(user['id']))
print('Finished upserting users')
# Out:
# Upserted item with id 97001
# Upserted item with id 97002
# Upserted item with id 97003
# Upserted item with id 97004
# Upserted item with id 97005
# Upserted item with id 97006
# Upserted item with id 97007
# Upserted item with id 97008
# Upserted item with id 97009
# Upserted item with id 97010
# Upserted item with id 97011
# Upserted item with id 97012
# Upserted item with id 97013
# Upserted item with id 97014
# Upserted item with id 97015
# Upserted item with id 97016
# Upserted item with id 97017
# Upserted item with id 97018
# Upserted item with id 97019
# Upserted item with id 97020
# Upserted item with id 97021
# Upserted item with id 97022
# Upserted item with id 97023
# Upserted item with id 97024
# Upserted item with id 97025
# Upserted item with id 97026
# Upserted item with id 97027
# Upserted item with id 97028
# Upserted item with id 97029
# Upserted item with id 97030
# Upserted item with id 97031
# Upserted item with id 97032
# Upserted item with id 97033
# Upserted item with id 97034
# Upserted item with id 97035
# Upserted item with id 97036
# Upserted item with id 97037
# Upserted item with id 97038
# Upserted item with id 97039
# Upserted item with id 97040
# Upserted item with id 97041
# Upserted item with id 97042
# Upserted item with id 97043
# Upserted item with id 97044
# Upserted item with id 97045
# Upserted item with id 97046
# Upserted item with id 97047
# Upserted item with id 97048
# Upserted item with id 97049
# Upserted item with id 97050
# Upserted item with id 97051
# Upserted item with id 97052
# Upserted item with id 97053
# Upserted item with id 97054
# Upserted item with id 97055
# Upserted item with id 97056
# Upserted item with id 97057
# Upserted item with id 97058
# Upserted item with id 97059
# Upserted item with id 97060
# Upserted item with id 97061
# Upserted item with id 97062
# Upserted item with id 97063
# Upserted item with id 97064
# Upserted item with id 97065
# Upserted item with id 97066
# Upserted item with id 97067
# Upserted item with id 97068
# Upserted item with id 97069
# Upserted item with id 97070
# Upserted item with id 97071
# Upserted item with id 97072
# Upserted item with id 97073
# Upserted item with id 97074
# Upserted item with id 97075
# Upserted item with id 97076
# Upserted item with id 97077
# Upserted item with id 97078
# Upserted item with id 97079
# Upserted item with id 97080
# Upserted item with id 97081
# Upserted item with id 97082
# Upserted item with id 97083
# Upserted item with id 97084
# Upserted item with id 97085
# Upserted item with id 97086
# Upserted item with id 97087
# Upserted item with id 97088
# Upserted item with id 97089
# Upserted item with id 97090
# Upserted item with id 97091
# Upserted item with id 97092
# Upserted item with id 97093
# Upserted item with id 97094
# Upserted item with id 97095
# Upserted item with id 97096
# Upserted item with id 97097
# Upserted item with id 97098
# Upserted item with id 97099
# Upserted item with id 97100
# Upserted item with id 97101
# Upserted item with id 97102
# Upserted item with id 97103
# Upserted item with id 97104
# Upserted item with id 97105
# Upserted item with id 97106
# Upserted item with id 97107
# Upserted item with id 97108
# Upserted item with id 97109
# Upserted item with id 97110
# Upserted item with id 97111
# Upserted item with id 97112
# Upserted item with id 97113
# Upserted item with id 97114
# Upserted item with id 97115
# Upserted item with id 97116
# Upserted item with id 97117
# Upserted item with id 97118
# Upserted item with id 97119
# Upserted item with id 97120
# Upserted item with id 97121
# Upserted item with id 97122
# Upserted item with id 97123
# Upserted item with id 97124
# Upserted item with id 97125
# Upserted item with id 97126
# Upserted item with id 97127
# Upserted item with id 97128
# Upserted item with id 97129
# Upserted item with id 97130
# Upserted item with id 97131
# Upserted item with id 97132
# Upserted item with id 97133
# Upserted item with id 97134
# Upserted item with id 97135
# Upserted item with id 97136
# Upserted item with id 97137
# Upserted item with id 97138
# Upserted item with id 97139
# Upserted item with id 97140
# Upserted item with id 97141
# Upserted item with id 97142
# Upserted item with id 97143
# Upserted item with id 97144
# Upserted item with id 97145
# Upserted item with id 97146
# Upserted item with id 97147
# Upserted item with id 97148
# Upserted item with id 97149
# Upserted item with id 97150
# Upserted item with id 97151
# Upserted item with id 97152
# Upserted item with id 97153
# Upserted item with id 97154
# Upserted item with id 97155
# Upserted item with id 97156
# Upserted item with id 97157
# Upserted item with id 97158
# Upserted item with id 97159
# Upserted item with id 97160
# Upserted item with id 97161
# Upserted item with id 97162
# Upserted item with id 97163
# Upserted item with id 97164
# Upserted item with id 97165
# Upserted item with id 97166
# Upserted item with id 97167
# Upserted item with id 97168
# Upserted item with id 97169
# Upserted item with id 97170
# Upserted item with id 97171
# Upserted item with id 97172
# Upserted item with id 97173
# Upserted item with id 97174
# Upserted item with id 97175
# Upserted item with id 97176
# Upserted item with id 97177
# Upserted item with id 97178
# Upserted item with id 97179
# Upserted item with id 97180
# Upserted item with id 97181
# Upserted item with id 97182
# Upserted item with id 97183
# Upserted item with id 97184
# Upserted item with id 97185
# Upserted item with id 97186
# Upserted item with id 97187
# Upserted item with id 97188
# Upserted item with id 97189
# Upserted item with id 97190
# Upserted item with id 97191
# Upserted item with id 97192
# Upserted item with id 97193
# Upserted item with id 97194
# Upserted item with id 97195
# Upserted item with id 97196
# Upserted item with id 97197
# Upserted item with id 97198
# Upserted item with id 97199
# Upserted item with id 97200
# Upserted item with id 97201
# Upserted item with id 97202
# Upserted item with id 97203
# Upserted item with id 97204
# Upserted item with id 97205
# Upserted item with id 97206
# Upserted item with id 97207
# Upserted item with id 97208
# Upserted item with id 97209
# Upserted item with id 97210
# Upserted item with id 97211
# Upserted item with id 97212
# Upserted item with id 97213
# Upserted item with id 97214
# Upserted item with id 97215
# Upserted item with id 97216
# Upserted item with id 97217
# Upserted item with id 97218
# Upserted item with id 97219
# Upserted item with id 97220
# Upserted item with id 97221
# Upserted item with id 97222
# Upserted item with id 97223
# Upserted item with id 97224
# Upserted item with id 97225
# Upserted item with id 97226
# Upserted item with id 97227
# Upserted item with id 97228
# Upserted item with id 97229
# Upserted item with id 97230
# Upserted item with id 97231
# Upserted item with id 97232
# Upserted item with id 97233
# Upserted item with id 97234
# Upserted item with id 97235
# Upserted item with id 97236
# Upserted item with id 97237
# Upserted item with id 97238
# Upserted item with id 97239
# Upserted item with id 97240
# Upserted item with id 97241
# Upserted item with id 97242
# Upserted item with id 97243
# Upserted item with id 97244
# Upserted item with id 97245
# Upserted item with id 97246
# Upserted item with id 97247
# Upserted item with id 97248
# Upserted item with id 97249
# Upserted item with id 97250
# Upserted item with id 97251
# Upserted item with id 97252
# Upserted item with id 97253
# Upserted item with id 97254
# Upserted item with id 97255
# Upserted item with id 97256
# Upserted item with id 97257
# Upserted item with id 97258
# Upserted item with id 97259
# Upserted item with id 97260
# Upserted item with id 97261
# Upserted item with id 97262
# Upserted item with id 97263
# Upserted item with id 97264
# Upserted item with id 97265
# Upserted item with id 97266
# Upserted item with id 97267
# Upserted item with id 97268
# Upserted item with id 97269
# Upserted item with id 97270
# Upserted item with id 97271
# Upserted item with id 97272
# Upserted item with id 97273
# Upserted item with id 97274
# Upserted item with id 97275
# Upserted item with id 97276
# Upserted item with id 97277
# Upserted item with id 97278
# Upserted item with id 97279
# Upserted item with id 97280
# Upserted item with id 97281
# Upserted item with id 97282
# Upserted item with id 97283
# Upserted item with id 97284
# Upserted item with id 97285
# Upserted item with id 97286
# Upserted item with id 97287
# Upserted item with id 97288
# Upserted item with id 97289
# Upserted item with id 97290
# Upserted item with id 97291
# Upserted item with id 97292
# Upserted item with id 97293
# Upserted item with id 97294
# Upserted item with id 97295
# Upserted item with id 97296
# Upserted item with id 97297
# Upserted item with id 97298
# Upserted item with id 97299
# Upserted item with id 97300
# Upserted item with id 97301
# Upserted item with id 97302
# Upserted item with id 97303
# Upserted item with id 97304
# Upserted item with id 97305
# Upserted item with id 97306
# Upserted item with id 97307
# Upserted item with id 97308
# Upserted item with id 97309
# Upserted item with id 97310
# Upserted item with id 97311
# Upserted item with id 97312
# Upserted item with id 97313
# Upserted item with id 97314
# Upserted item with id 97315
# Upserted item with id 97316
# Upserted item with id 97317
# Upserted item with id 97318
# Upserted item with id 97319
# Upserted item with id 97320
# Upserted item with id 97321
# Upserted item with id 97322
# Upserted item with id 97323
# Upserted item with id 97324
# Upserted item with id 97325
# Upserted item with id 97326
# Upserted item with id 97327
# Upserted item with id 97328
# Upserted item with id 97329
# Upserted item with id 97330
# Upserted item with id 97331
# Upserted item with id 97332
# Upserted item with id 97333
# Upserted item with id 97334
# Upserted item with id 97335
# Upserted item with id 97336
# Upserted item with id 97337
# Upserted item with id 97338
# Upserted item with id 97339
# Upserted item with id 97340
# Upserted item with id 97341
# Upserted item with id 97342
# Upserted item with id 97343
# Upserted item with id 97344
# Upserted item with id 97345
# Upserted item with id 97346
# Upserted item with id 97347
# Upserted item with id 97348
# Upserted item with id 97349
# Upserted item with id 97350
# Upserted item with id 97351
# Upserted item with id 97352
# Upserted item with id 97353
# Upserted item with id 97354
# Upserted item with id 97355
# Upserted item with id 97356
# Upserted item with id 97357
# Upserted item with id 97358
# Upserted item with id 97359
# Upserted item with id 97360
# Upserted item with id 97361
# Upserted item with id 97362
# Upserted item with id 97363
# Upserted item with id 97364
# Upserted item with id 97365
# Upserted item with id 97366
# Upserted item with id 97367
# Upserted item with id 97368
# Upserted item with id 97369
# Upserted item with id 97370
# Upserted item with id 97371
# Upserted item with id 97372
# Upserted item with id 97373
# Upserted item with id 97374
# Upserted item with id 97375
# Upserted item with id 97376
# Upserted item with id 97377
# Upserted item with id 97378
# Upserted item with id 97379
# Upserted item with id 97380
# Upserted item with id 97381
# Upserted item with id 97382
# Upserted item with id 97383
# Upserted item with id 97384
# Upserted item with id 97385
# Upserted item with id 97386
# Upserted item with id 97387
# Upserted item with id 97388
# Upserted item with id 97389
# Upserted item with id 97390
# Upserted item with id 97391
# Upserted item with id 97392
# Upserted item with id 97393
# Upserted item with id 97394
# Upserted item with id 97395
# Upserted item with id 97396
# Upserted item with id 97397
# Upserted item with id 97398
# Upserted item with id 97399
# Upserted item with id 97400
# Upserted item with id 97401
# Upserted item with id 97402
# Upserted item with id 97403
# Upserted item with id 97404
# Upserted item with id 97405
# Upserted item with id 97406
# Upserted item with id 97407
# Upserted item with id 97408
# Upserted item with id 97409
# Upserted item with id 97410
# Upserted item with id 97411
# Upserted item with id 97412
# Upserted item with id 97413
# Upserted item with id 97414
# Upserted item with id 97415
# Upserted item with id 97416
# Upserted item with id 97417
# Upserted item with id 97418
# Upserted item with id 97419
# Upserted item with id 97420
# Upserted item with id 97421
# Upserted item with id 97422
# Upserted item with id 97423
# Upserted item with id 97424
# Upserted item with id 97425
# Upserted item with id 97426
# Upserted item with id 97427
# Upserted item with id 97428
# Upserted item with id 97429
# Upserted item with id 97430
# Upserted item with id 97431
# Upserted item with id 97432
# Upserted item with id 97433
# Upserted item with id 97434
# Upserted item with id 97435
# Upserted item with id 97436
# Upserted item with id 97437
# Upserted item with id 97438
# Upserted item with id 97439
# Upserted item with id 97440
# Upserted item with id 97441
# Upserted item with id 97442
# Upserted item with id 97443
# Upserted item with id 97444
# Upserted item with id 97445
# Upserted item with id 97446
# Upserted item with id 97447
# Upserted item with id 97448
# Upserted item with id 97449
# Upserted item with id 97450
# Upserted item with id 97451
# Upserted item with id 97452
# Upserted item with id 97453
# Upserted item with id 97454
# Upserted item with id 97455
# Upserted item with id 97456
# Upserted item with id 97457
# Upserted item with id 97458
# Upserted item with id 97459
# Upserted item with id 97460
# Upserted item with id 97461
# Upserted item with id 97462
# Upserted item with id 97463
# Upserted item with id 97464
# Upserted item with id 97465
# Upserted item with id 97466
# Upserted item with id 97467
# Upserted item with id 97468
# Upserted item with id 97469
# Upserted item with id 97470
# Upserted item with id 97471
# Upserted item with id 97472
# Upserted item with id 97473
# Upserted item with id 97474
# Upserted item with id 97475
# Upserted item with id 97476
# Upserted item with id 97477
# Upserted item with id 97478
# Upserted item with id 97479
# Upserted item with id 97480
# Upserted item with id 97481
# Upserted item with id 97482
# Upserted item with id 97483
# Upserted item with id 97484
# Upserted item with id 97485
# Upserted item with id 97486
# Upserted item with id 97487
# Upserted item with id 97488
# Upserted item with id 97489
# Upserted item with id 97490
# Upserted item with id 97491
# Upserted item with id 97492
# Upserted item with id 97493
# Upserted item with id 97494
# Upserted item with id 97495
# Upserted item with id 97496
# Upserted item with id 97497
# Upserted item with id 97498
# Upserted item with id 97499
# Upserted item with id 97500
# Upserted item with id 97501
# Upserted item with id 97502
# Upserted item with id 97503
# Upserted item with id 97504
# Upserted item with id 97505
# Upserted item with id 97506
# Upserted item with id 97507
# Upserted item with id 97508
# Upserted item with id 97509
# Upserted item with id 97510
# Upserted item with id 97511
# Upserted item with id 97512
# Upserted item with id 97513
# Upserted item with id 97514
# Upserted item with id 97515
# Upserted item with id 97516
# Upserted item with id 97517
# Upserted item with id 97518
# Upserted item with id 97519
# Upserted item with id 97520
# Upserted item with id 97521
# Upserted item with id 97522
# Upserted item with id 97523
# Upserted item with id 97524
# Upserted item with id 97525
# Upserted item with id 97526
# Upserted item with id 97527
# Upserted item with id 97528
# Upserted item with id 97529
# Upserted item with id 97530
# Upserted item with id 97531
# Upserted item with id 97532
# Upserted item with id 97533
# Upserted item with id 97534
# Upserted item with id 97535
# Upserted item with id 97536
# Upserted item with id 97537
# Upserted item with id 97538
# Upserted item with id 97539
# Upserted item with id 97540
# Upserted item with id 97541
# Upserted item with id 97542
# Upserted item with id 97543
# Upserted item with id 97544
# Upserted item with id 97545
# Upserted item with id 97546
# Upserted item with id 97547
# Upserted item with id 97548
# Upserted item with id 97549
# Upserted item with id 97550
# Upserted item with id 97551
# Upserted item with id 97552
# Upserted item with id 97553
# Upserted item with id 97554
# Upserted item with id 97555
# Upserted item with id 97556
# Upserted item with id 97557
# Upserted item with id 97558
# Upserted item with id 97559
# Upserted item with id 97560
# Upserted item with id 97561
# Upserted item with id 97562
# Upserted item with id 97563
# Upserted item with id 97564
# Upserted item with id 97565
# Upserted item with id 97566
# Upserted item with id 97567
# Upserted item with id 97568
# Upserted item with id 97569
# Upserted item with id 97570
# Upserted item with id 97571
# Upserted item with id 97572
# Upserted item with id 97573
# Upserted item with id 97574
# Upserted item with id 97575
# Upserted item with id 97576
# Upserted item with id 97577
# Upserted item with id 97578
# Upserted item with id 97579
# Upserted item with id 97580
# Upserted item with id 97581
# Upserted item with id 97582
# Upserted item with id 97583
# Upserted item with id 97584
# Upserted item with id 97585
# Upserted item with id 97586
# Upserted item with id 97587
# Upserted item with id 97588
# Upserted item with id 97589
# Upserted item with id 97590
# Upserted item with id 97591
# Upserted item with id 97592
# Upserted item with id 97593
# Upserted item with id 97594
# Upserted item with id 97595
# Upserted item with id 97596
# Upserted item with id 97597
# Upserted item with id 97598
# Upserted item with id 97599
# Upserted item with id 97600
# Upserted item with id 97601
# Upserted item with id 97602
# Upserted item with id 97603
# Upserted item with id 97604
# Upserted item with id 97605
# Upserted item with id 97606
# Upserted item with id 97607
# Upserted item with id 97608
# Upserted item with id 97609
# Upserted item with id 97610
# Upserted item with id 97611
# Upserted item with id 97612
# Upserted item with id 97613
# Upserted item with id 97614
# Upserted item with id 97615
# Upserted item with id 97616
# Upserted item with id 97617
# Upserted item with id 97618
# Upserted item with id 97619
# Upserted item with id 97620
# Upserted item with id 97621
# Upserted item with id 97622
# Upserted item with id 97623
# Upserted item with id 97624
# Upserted item with id 97625
# Upserted item with id 97626
# Upserted item with id 97627
# Upserted item with id 97628
# Upserted item with id 97629
# Upserted item with id 97630
# Upserted item with id 97631
# Upserted item with id 97632
# Upserted item with id 97633
# Upserted item with id 97634
# Upserted item with id 97635
# Upserted item with id 97636
# Upserted item with id 97637
# Upserted item with id 97638
# Upserted item with id 97639
# Upserted item with id 97640
# Upserted item with id 97641
# Upserted item with id 97642
# Upserted item with id 97643
# Upserted item with id 97644
# Upserted item with id 97645
# Upserted item with id 97646
# Upserted item with id 97647
# Upserted item with id 97648
# Upserted item with id 97649
# Upserted item with id 97650
# Upserted item with id 97651
# Upserted item with id 97652
# Upserted item with id 97653
# Upserted item with id 97654
# Upserted item with id 97655
# Upserted item with id 97656
# Upserted item with id 97657
# Upserted item with id 97658
# Upserted item with id 97659
# Upserted item with id 97660
# Upserted item with id 97661
# Upserted item with id 97662
# Upserted item with id 97663
# Upserted item with id 97664
# Upserted item with id 97665
# Upserted item with id 97666
# Upserted item with id 97667
# Upserted item with id 97668
# Upserted item with id 97669
# Upserted item with id 97670
# Upserted item with id 97671
# Upserted item with id 97672
# Upserted item with id 97673
# Upserted item with id 97674
# Upserted item with id 97675
# Upserted item with id 97676
# Upserted item with id 97677
# Upserted item with id 97678
# Upserted item with id 97679
# Upserted item with id 97680
# Upserted item with id 97681
# Upserted item with id 97682
# Upserted item with id 97683
# Upserted item with id 97684
# Upserted item with id 97685
# Upserted item with id 97686
# Upserted item with id 97687
# Upserted item with id 97688
# Upserted item with id 97689
# Upserted item with id 97690
# Upserted item with id 97691
# Upserted item with id 97692
# Upserted item with id 97693
# Upserted item with id 97694
# Upserted item with id 97695
# Upserted item with id 97696
# Upserted item with id 97697
# Upserted item with id 97698
# Upserted item with id 97699
# Upserted item with id 97700
# Upserted item with id 97701
# Upserted item with id 97702
# Upserted item with id 97703
# Upserted item with id 97704
# Upserted item with id 97705
# Upserted item with id 97706
# Upserted item with id 97707
# Upserted item with id 97708
# Upserted item with id 97709
# Upserted item with id 97710
# Upserted item with id 97711
# Upserted item with id 97712
# Upserted item with id 97713
# Upserted item with id 97714
# Upserted item with id 97715
# Upserted item with id 97716
# Upserted item with id 97717
# Upserted item with id 97718
# Upserted item with id 97719
# Upserted item with id 97720
# Upserted item with id 97721
# Upserted item with id 97722
# Upserted item with id 97723
# Upserted item with id 97724
# Upserted item with id 97725
# Upserted item with id 97726
# Upserted item with id 97727
# Upserted item with id 97728
# Upserted item with id 97729
# Upserted item with id 97730
# Upserted item with id 97731
# Upserted item with id 97732
# Upserted item with id 97733
# Upserted item with id 97734
# Upserted item with id 97735
# Upserted item with id 97736
# Upserted item with id 97737
# Upserted item with id 97738
# Upserted item with id 97739
# Upserted item with id 97740
# Upserted item with id 97741
# Upserted item with id 97742
# Upserted item with id 97743
# Upserted item with id 97744
# Upserted item with id 97745
# Upserted item with id 97746
# Upserted item with id 97747
# Upserted item with id 97748
# Upserted item with id 97749
# Upserted item with id 97750
# Upserted item with id 97751
# Upserted item with id 97752
# Upserted item with id 97753
# Upserted item with id 97754
# Upserted item with id 97755
# Upserted item with id 97756
# Upserted item with id 97757
# Upserted item with id 97758
# Upserted item with id 97759
# Upserted item with id 97760
# Upserted item with id 97761
# Upserted item with id 97762
# Upserted item with id 97763
# Upserted item with id 97764
# Upserted item with id 97765
# Upserted item with id 97766
# Upserted item with id 97767
# Upserted item with id 97768
# Upserted item with id 97769
# Upserted item with id 97770
# Upserted item with id 97771
# Upserted item with id 97772
# Upserted item with id 97773
# Upserted item with id 97774
# Upserted item with id 97775
# Upserted item with id 97776
# Upserted item with id 97777
# Upserted item with id 97778
# Upserted item with id 97779
# Upserted item with id 97780
# Upserted item with id 97781
# Upserted item with id 97782
# Upserted item with id 97783
# Upserted item with id 97784
# Upserted item with id 97785
# Upserted item with id 97786
# Upserted item with id 97787
# Upserted item with id 97788
# Upserted item with id 97789
# Upserted item with id 97790
# Upserted item with id 97791
# Upserted item with id 97792
# Upserted item with id 97793
# Upserted item with id 97794
# Upserted item with id 97795
# Upserted item with id 97796
# Upserted item with id 97797
# Upserted item with id 97798
# Upserted item with id 97799
# Upserted item with id 97800
# Upserted item with id 97801
# Upserted item with id 97802
# Upserted item with id 97803
# Upserted item with id 97804
# Upserted item with id 97805
# Upserted item with id 97806
# Upserted item with id 97807
# Upserted item with id 97808
# Upserted item with id 97809
# Upserted item with id 97810
# Upserted item with id 97811
# Upserted item with id 97812
# Upserted item with id 97813
# Upserted item with id 97814
# Upserted item with id 97815
# Upserted item with id 97816
# Upserted item with id 97817
# Upserted item with id 97818
# Upserted item with id 97819
# Upserted item with id 97820
# Upserted item with id 97821
# Upserted item with id 97822
# Upserted item with id 97823
# Upserted item with id 97824
# Upserted item with id 97825
# Upserted item with id 97826
# Upserted item with id 97827
# Upserted item with id 97828
# Upserted item with id 97829
# Upserted item with id 97830
# Upserted item with id 97831
# Upserted item with id 97832
# Upserted item with id 97833
# Upserted item with id 97834
# Upserted item with id 97835
# Upserted item with id 97836
# Upserted item with id 97837
# Upserted item with id 97838
# Upserted item with id 97839
# Upserted item with id 97840
# Upserted item with id 97841
# Upserted item with id 97842
# Upserted item with id 97843
# Upserted item with id 97844
# Upserted item with id 97845
# Upserted item with id 97846
# Upserted item with id 97847
# Upserted item with id 97848
# Upserted item with id 97849
# Upserted item with id 97850
# Upserted item with id 97851
# Upserted item with id 97852
# Upserted item with id 97853
# Upserted item with id 97854
# Upserted item with id 97855
# Upserted item with id 97856
# Upserted item with id 97857
# Upserted item with id 97858
# Upserted item with id 97859
# Upserted item with id 97860
# Upserted item with id 97861
# Upserted item with id 97862
# Upserted item with id 97863
# Upserted item with id 97864
# Upserted item with id 97865
# Upserted item with id 97866
# Upserted item with id 97867
# Upserted item with id 97868
# Upserted item with id 97869
# Upserted item with id 97870
# Upserted item with id 97871
# Upserted item with id 97872
# Upserted item with id 97873
# Upserted item with id 97874
# Upserted item with id 97875
# Upserted item with id 97876
# Upserted item with id 97877
# Upserted item with id 97878
# Upserted item with id 97879
# Upserted item with id 97880
# Upserted item with id 97881
# Upserted item with id 97882
# Upserted item with id 97883
# Upserted item with id 97884
# Upserted item with id 97885
# Upserted item with id 97886
# Upserted item with id 97887
# Upserted item with id 97888
# Upserted item with id 97889
# Upserted item with id 97890
# Upserted item with id 97891
# Upserted item with id 97892
# Upserted item with id 97893
# Upserted item with id 97894
# Upserted item with id 97895
# Upserted item with id 97896
# Upserted item with id 97897
# Upserted item with id 97898
# Upserted item with id 97899
# Upserted item with id 97900
# Upserted item with id 97901
# Upserted item with id 97902
# Upserted item with id 97903
# Upserted item with id 97904
# Upserted item with id 97905
# Upserted item with id 97906
# Upserted item with id 97907
# Upserted item with id 97908
# Upserted item with id 97909
# Upserted item with id 97910
# Upserted item with id 97911
# Upserted item with id 97912
# Upserted item with id 97913
# Upserted item with id 97914
# Upserted item with id 97915
# Upserted item with id 97916
# Upserted item with id 97917
# Upserted item with id 97918
# Upserted item with id 97919
# Upserted item with id 97920
# Upserted item with id 97921
# Upserted item with id 97922
# Upserted item with id 97923
# Upserted item with id 97924
# Upserted item with id 97925
# Upserted item with id 97926
# Upserted item with id 97927
# Upserted item with id 97928
# Upserted item with id 97929
# Upserted item with id 97930
# Upserted item with id 97931
# Upserted item with id 97932
# Upserted item with id 97933
# Upserted item with id 97934
# Upserted item with id 97935
# Upserted item with id 97936
# Upserted item with id 97937
# Upserted item with id 97938
# Upserted item with id 97939
# Upserted item with id 97940
# Upserted item with id 97941
# Upserted item with id 97942
# Upserted item with id 97943
# Upserted item with id 97944
# Upserted item with id 97945
# Upserted item with id 97946
# Upserted item with id 97947
# Upserted item with id 97948
# Upserted item with id 97949
# Upserted item with id 97950
# Upserted item with id 97951
# Upserted item with id 97952
# Upserted item with id 97953
# Upserted item with id 97954
# Upserted item with id 97955
# Upserted item with id 97956
# Upserted item with id 97957
# Upserted item with id 97958
# Upserted item with id 97959
# Upserted item with id 97960
# Upserted item with id 97961
# Upserted item with id 97962
# Upserted item with id 97963
# Upserted item with id 97964
# Upserted item with id 97965
# Upserted item with id 97966
# Upserted item with id 97967
# Upserted item with id 97968
# Upserted item with id 97969
# Upserted item with id 97970
# Upserted item with id 97971
# Upserted item with id 97972
# Upserted item with id 97973
# Upserted item with id 97974
# Upserted item with id 97975
# Upserted item with id 97976
# Upserted item with id 97977
# Upserted item with id 97978
# Upserted item with id 97979
# Upserted item with id 97980
# Upserted item with id 97981
# Upserted item with id 97982
# Upserted item with id 97983
# Upserted item with id 97984
# Upserted item with id 97985
# Upserted item with id 97986
# Upserted item with id 97987
# Upserted item with id 97988
# Upserted item with id 97989
# Upserted item with id 97990
# Upserted item with id 97991
# Upserted item with id 97992
# Upserted item with id 97993
# Upserted item with id 97994
# Upserted item with id 97995
# Upserted item with id 97996
# Upserted item with id 97997
# Upserted item with id 97998
# Upserted item with id 97999
# Upserted item with id 98000
# Upserted item with id 98001
# Upserted item with id 98002
# Upserted item with id 98003
# Upserted item with id 98004
# Upserted item with id 98005
# Upserted item with id 98006
# Upserted item with id 98007
# Upserted item with id 98008
# Upserted item with id 98009
# Upserted item with id 98010
# Upserted item with id 98011
# Upserted item with id 98012
# Upserted item with id 98013
# Upserted item with id 98014
# Upserted item with id 98015
# Upserted item with id 98016
# Upserted item with id 98017
# Upserted item with id 98018
# Upserted item with id 98019
# Upserted item with id 98020
# Upserted item with id 98021
# Upserted item with id 98022
# Upserted item with id 98023
# Upserted item with id 98024
# Upserted item with id 98025
# Upserted item with id 98026
# Upserted item with id 98027
# Upserted item with id 98028
# Upserted item with id 98029
# Upserted item with id 98030
# Upserted item with id 98031
# Upserted item with id 98032
# Upserted item with id 98033
# Upserted item with id 98034
# Upserted item with id 98035
# Upserted item with id 98036
# Upserted item with id 98037
# Upserted item with id 98038
# Upserted item with id 98039
# Upserted item with id 98040
# Upserted item with id 98041
# Upserted item with id 98042
# Upserted item with id 98043
# Upserted item with id 98044
# Upserted item with id 98045
# Upserted item with id 98046
# Upserted item with id 98047
# Upserted item with id 98048
# Upserted item with id 98049
# Upserted item with id 98050
# Upserted item with id 98051
# Upserted item with id 98052
# Upserted item with id 98053
# Upserted item with id 98054
# Upserted item with id 98055
# Upserted item with id 98056
# Upserted item with id 98057
# Upserted item with id 98058
# Upserted item with id 98059
# Upserted item with id 98060
# Upserted item with id 98061
# Upserted item with id 98062
# Upserted item with id 98063
# Upserted item with id 98064
# Upserted item with id 98065
# Upserted item with id 98066
# Upserted item with id 98067
# Upserted item with id 98068
# Upserted item with id 98069
# Upserted item with id 98070
# Upserted item with id 98071
# Upserted item with id 98072
# Upserted item with id 98073
# Upserted item with id 98074
# Upserted item with id 98075
# Upserted item with id 98076
# Upserted item with id 98077
# Upserted item with id 98078
# Upserted item with id 98079
# Upserted item with id 98080
# Upserted item with id 98081
# Upserted item with id 98082
# Upserted item with id 98083
# Upserted item with id 98084
# Upserted item with id 98085
# Upserted item with id 98086
# Upserted item with id 98087
# Upserted item with id 98088
# Upserted item with id 98089
# Upserted item with id 98090
# Upserted item with id 98091
# Upserted item with id 98092
# Upserted item with id 98093
# Upserted item with id 98094
# Upserted item with id 98095
# Upserted item with id 98096
# Upserted item with id 98097
# Upserted item with id 98098
# Upserted item with id 98099
# Upserted item with id 98100
# Upserted item with id 98101
# Upserted item with id 98102
# Upserted item with id 98103
# Upserted item with id 98104
# Upserted item with id 98105
# Upserted item with id 98106
# Upserted item with id 98107
# Upserted item with id 98108
# Upserted item with id 98109
# Upserted item with id 98110
# Upserted item with id 98111
# Upserted item with id 98112
# Upserted item with id 98113
# Upserted item with id 98114
# Upserted item with id 98115
# Upserted item with id 98116
# Upserted item with id 98117
# Upserted item with id 98118
# Upserted item with id 98119
# Upserted item with id 98120
# Upserted item with id 98121
# Upserted item with id 98122
# Upserted item with id 98123
# Upserted item with id 98124
# Upserted item with id 98125
# Upserted item with id 98126
# Upserted item with id 98127
# Upserted item with id 98128
# Upserted item with id 98129
# Upserted item with id 98130
# Upserted item with id 98131
# Upserted item with id 98132
# Upserted item with id 98133
# Upserted item with id 98134
# Upserted item with id 98135
# Upserted item with id 98136
# Upserted item with id 98137
# Upserted item with id 98138
# Upserted item with id 98139
# Upserted item with id 98140
# Upserted item with id 98141
# Upserted item with id 98142
# Upserted item with id 98143
# Upserted item with id 98144
# Upserted item with id 98145
# Upserted item with id 98146
# Upserted item with id 98147
# Upserted item with id 98148
# Upserted item with id 98149
# Upserted item with id 98150
# Upserted item with id 98151
# Upserted item with id 98152
# Upserted item with id 98153
# Upserted item with id 98154
# Upserted item with id 98155
# Upserted item with id 98156
# Upserted item with id 98157
# Upserted item with id 98158
# Upserted item with id 98159
# Upserted item with id 98160
# Upserted item with id 98161
# Upserted item with id 98162
# Upserted item with id 98163
# Upserted item with id 98164
# Upserted item with id 98165
# Upserted item with id 98166
# Upserted item with id 98167
# Upserted item with id 98168
# Upserted item with id 98169
# Upserted item with id 98170
# Upserted item with id 98171
# Upserted item with id 98172
# Upserted item with id 98173
# Upserted item with id 98174
# Upserted item with id 98175
# Upserted item with id 98176
# Upserted item with id 98177
# Upserted item with id 98178
# Upserted item with id 98179
# Upserted item with id 98180
# Upserted item with id 98181
# Upserted item with id 98182
# Upserted item with id 98183
# Upserted item with id 98184
# Upserted item with id 98185
# Upserted item with id 98186
# Upserted item with id 98187
# Upserted item with id 98188
# Upserted item with id 98189
# Upserted item with id 98190
# Upserted item with id 98191
# Upserted item with id 98192
# Upserted item with id 98193
# Upserted item with id 98194
# Upserted item with id 98195
# Upserted item with id 98196
# Upserted item with id 98197
# Upserted item with id 98198
# Upserted item with id 98199
# Upserted item with id 98200
# Upserted item with id 98201
# Upserted item with id 98202
# Upserted item with id 98203
# Upserted item with id 98204
# Upserted item with id 98205
# Upserted item with id 98206
# Upserted item with id 98207
# Upserted item with id 98208
# Upserted item with id 98209
# Upserted item with id 98210
# Upserted item with id 98211
# Upserted item with id 98212
# Upserted item with id 98213
# Upserted item with id 98214
# Upserted item with id 98215
# Upserted item with id 98216
# Upserted item with id 98217
# Upserted item with id 98218
# Upserted item with id 98219
# Upserted item with id 98220
# Upserted item with id 98221
# Upserted item with id 98222
# Upserted item with id 98223
# Upserted item with id 98224
# Upserted item with id 98225
# Upserted item with id 98226
# Upserted item with id 98227
# Upserted item with id 98228
# Upserted item with id 98229
# Upserted item with id 98230
# Upserted item with id 98231
# Upserted item with id 98232
# Upserted item with id 98233
# Upserted item with id 98234
# Upserted item with id 98235
# Upserted item with id 98236
# Upserted item with id 98237
# Upserted item with id 98238
# Upserted item with id 98239
# Upserted item with id 98240
# Upserted item with id 98241
# Upserted item with id 98242
# Upserted item with id 98243
# Upserted item with id 98244
# Upserted item with id 98245
# Upserted item with id 98246
# Upserted item with id 98247
# Upserted item with id 98248
# Upserted item with id 98249
# Upserted item with id 98250
# Upserted item with id 98251
# Upserted item with id 98252
# Upserted item with id 98253
# Upserted item with id 98254
# Upserted item with id 98255
# Upserted item with id 98256
# Upserted item with id 98257
# Upserted item with id 98258
# Upserted item with id 98259
# Upserted item with id 98260
# Upserted item with id 98261
# Upserted item with id 98262
# Upserted item with id 98263
# Upserted item with id 98264
# Upserted item with id 98265
# Upserted item with id 98266
# Upserted item with id 98267
# Upserted item with id 98268
# Upserted item with id 98269
# Upserted item with id 98270
# Upserted item with id 98271
# Upserted item with id 98272
# Upserted item with id 98273
# Upserted item with id 98274
# Upserted item with id 98275
# Upserted item with id 98276
# Upserted item with id 98277
# Upserted item with id 98278
# Upserted item with id 98279
# Upserted item with id 98280
# Upserted item with id 98281
# Upserted item with id 98282
# Upserted item with id 98283
# Upserted item with id 98284
# Upserted item with id 98285
# Upserted item with id 98286
# Upserted item with id 98287
# Upserted item with id 98288
# Upserted item with id 98289
# Upserted item with id 98290
# Upserted item with id 98291
# Upserted item with id 98292
# Upserted item with id 98293
# Upserted item with id 98294
# Upserted item with id 98295
# Upserted item with id 98296
# Upserted item with id 98297
# Upserted item with id 98298
# Upserted item with id 98299
# Upserted item with id 98300
# Upserted item with id 98301
# Upserted item with id 98302
# Upserted item with id 98303
# Upserted item with id 98304
# Upserted item with id 98305
# Upserted item with id 98306
# Upserted item with id 98307
# Upserted item with id 98308
# Upserted item with id 98309
# Upserted item with id 98310
# Upserted item with id 98311
# Upserted item with id 98312
# Upserted item with id 98313
# Upserted item with id 98314
# Upserted item with id 98315
# Upserted item with id 98316
# Upserted item with id 98317
# Upserted item with id 98318
# Upserted item with id 98319
# Upserted item with id 98320
# Upserted item with id 98321
# Upserted item with id 98322
# Upserted item with id 98323
# Upserted item with id 98324
# Upserted item with id 98325
# Upserted item with id 98326
# Upserted item with id 98327
# Upserted item with id 98328
# Upserted item with id 98329
# Upserted item with id 98330
# Upserted item with id 98331
# Upserted item with id 98332
# Upserted item with id 98333
# Upserted item with id 98334
# Upserted item with id 98335
# Upserted item with id 98336
# Upserted item with id 98338
# Upserted item with id 98339
# Upserted item with id 98340
# Upserted item with id 98341
# Upserted item with id 98342
# Upserted item with id 98343
# Upserted item with id 98344
# Upserted item with id 98345
# Upserted item with id 98346
# Upserted item with id 98347
# Upserted item with id 98348
# Upserted item with id 98349
# Upserted item with id 98350
# Upserted item with id 98351
# Upserted item with id 98352
# Upserted item with id 98353
# Upserted item with id 98354
# Upserted item with id 98355
# Upserted item with id 98356
# Upserted item with id 98357
# Upserted item with id 98358
# Upserted item with id 98359
# Upserted item with id 98360
# Upserted item with id 98361
# Upserted item with id 98362
# Upserted item with id 98363
# Upserted item with id 98364
# Upserted item with id 98365
# Upserted item with id 98366
# Upserted item with id 98367
# Upserted item with id 98368
# Upserted item with id 98369
# Upserted item with id 98370
# Upserted item with id 98371
# Upserted item with id 98372
# Upserted item with id 98373
# Upserted item with id 98374
# Upserted item with id 98375
# Upserted item with id 98376
# Upserted item with id 98377
# Upserted item with id 98378
# Upserted item with id 98379
# Upserted item with id 98380
# Upserted item with id 98381
# Upserted item with id 98382
# Upserted item with id 98383
# Upserted item with id 98384
# Upserted item with id 98385
# Upserted item with id 98386
# Upserted item with id 98387
# Upserted item with id 98388
# Upserted item with id 98389
# Upserted item with id 98390
# Upserted item with id 98391
# Upserted item with id 98392
# Upserted item with id 98393
# Upserted item with id 98394
# Upserted item with id 98395
# Upserted item with id 98396
# Upserted item with id 98397
# Upserted item with id 98398
# Upserted item with id 98399
# Upserted item with id 98400
# Upserted item with id 98401
# Upserted item with id 98402
# Upserted item with id 98403
# Upserted item with id 98404
# Upserted item with id 98405
# Upserted item with id 98406
# Upserted item with id 98407
# Upserted item with id 98408
# Upserted item with id 98409
# Upserted item with id 98410
# Upserted item with id 98411
# Upserted item with id 98412
# Upserted item with id 98413
# Upserted item with id 98414
# Upserted item with id 98415
# Upserted item with id 98416
# Upserted item with id 98417
# Upserted item with id 98418
# Upserted item with id 98419
# Upserted item with id 98420
# Upserted item with id 98421
# Upserted item with id 98422
# Upserted item with id 98423
# Upserted item with id 98424
# Upserted item with id 98425
# Upserted item with id 98426
# Upserted item with id 98427
# Upserted item with id 98428
# Upserted item with id 98429
# Upserted item with id 98430
# Upserted item with id 98431
# Upserted item with id 98432
# Upserted item with id 98433
# Upserted item with id 98434
# Upserted item with id 98435
# Upserted item with id 98436
# Upserted item with id 98437
# Upserted item with id 98438
# Upserted item with id 98439
# Upserted item with id 98440
# Upserted item with id 98441
# Upserted item with id 98442
# Upserted item with id 98443
# Upserted item with id 98444
# Upserted item with id 98445
# Upserted item with id 98446
# Upserted item with id 98447
# Upserted item with id 98448
# Upserted item with id 98449
# Upserted item with id 98450
# Upserted item with id 98451
# Upserted item with id 98452
# Upserted item with id 98453
# Upserted item with id 98454
# Upserted item with id 98455
# Upserted item with id 98456
# Upserted item with id 98457
# Upserted item with id 98458
# Upserted item with id 98459
# Upserted item with id 98460
# Upserted item with id 98461
# Upserted item with id 98462
# Upserted item with id 98463
# Upserted item with id 98464
# Upserted item with id 98465
# Upserted item with id 98466
# Upserted item with id 98467
# Upserted item with id 98468
# Upserted item with id 98469
# Upserted item with id 98470
# Upserted item with id 98471
# Upserted item with id 98472
# Upserted item with id 98473
# Upserted item with id 98474
# Upserted item with id 98475
# Upserted item with id 98476
# Upserted item with id 98477
# Upserted item with id 98478
# Upserted item with id 98479
# Upserted item with id 98480
# Upserted item with id 98481
# Upserted item with id 98482
# Upserted item with id 98483
# Upserted item with id 98484
# Upserted item with id 98485
# Upserted item with id 98486
# Upserted item with id 98487
# Upserted item with id 98488
# Upserted item with id 98489
# Upserted item with id 98490
# Upserted item with id 98491
# Upserted item with id 98492
# Upserted item with id 98493
# Upserted item with id 98494
# Upserted item with id 98495
# Upserted item with id 98496
# Upserted item with id 98497
# Upserted item with id 98498
# Upserted item with id 98499
# Upserted item with id 98500
# Upserted item with id 98501
# Upserted item with id 98502
# Upserted item with id 98503
# Upserted item with id 98504
# Upserted item with id 98505
# Upserted item with id 98506
# Upserted item with id 98507
# Upserted item with id 98508
# Upserted item with id 98509
# Upserted item with id 98510
# Upserted item with id 98511
# Upserted item with id 98512
# Upserted item with id 98513
# Upserted item with id 98514
# Upserted item with id 98515
# Upserted item with id 98516
# Upserted item with id 98517
# Upserted item with id 98518
# Upserted item with id 98519
# Upserted item with id 98520
# Upserted item with id 98521
# Upserted item with id 98522
# Upserted item with id 98523
# Upserted item with id 98524
# Upserted item with id 98525
# Upserted item with id 98526
# Upserted item with id 98527
# Upserted item with id 98528
# Upserted item with id 98529
# Upserted item with id 98530
# Upserted item with id 98531
# Upserted item with id 98532
# Upserted item with id 98533
# Upserted item with id 98534
# Upserted item with id 98535
# Upserted item with id 98536
# Upserted item with id 98537
# Upserted item with id 98538
# Upserted item with id 98539
# Upserted item with id 98540
# Upserted item with id 98541
# Upserted item with id 98542
# Upserted item with id 98543
# Upserted item with id 98544
# Upserted item with id 98545
# Upserted item with id 98546
# Upserted item with id 98547
# Upserted item with id 98548
# Upserted item with id 98549
# Upserted item with id 98550
# Upserted item with id 98551
# Upserted item with id 98552
# Upserted item with id 98553
# Upserted item with id 98554
# Upserted item with id 98555
# Upserted item with id 98556
# Upserted item with id 98557
# Upserted item with id 98558
# Upserted item with id 98559
# Upserted item with id 98560
# Upserted item with id 98561
# Upserted item with id 98562
# Upserted item with id 98563
# Upserted item with id 98564
# Upserted item with id 98565
# Upserted item with id 98566
# Upserted item with id 98567
# Upserted item with id 98568
# Upserted item with id 98569
# Upserted item with id 98570
# Upserted item with id 98571
# Upserted item with id 98572
# Upserted item with id 98573
# Upserted item with id 98574
# Upserted item with id 98575
# Upserted item with id 98576
# Upserted item with id 98577
# Upserted item with id 98578
# Upserted item with id 98579
# Upserted item with id 98580
# Upserted item with id 98581
# Upserted item with id 98582
# Upserted item with id 98583
# Upserted item with id 98584
# Upserted item with id 98585
# Upserted item with id 98586
# Upserted item with id 98587
# Upserted item with id 98588
# Upserted item with id 98589
# Upserted item with id 98590
# Upserted item with id 98591
# Upserted item with id 98592
# Upserted item with id 98593
# Upserted item with id 98594
# Upserted item with id 98595
# Upserted item with id 98596
# Upserted item with id 98597
# Upserted item with id 98598
# Upserted item with id 98599
# Upserted item with id 98600
# Upserted item with id 98601
# Upserted item with id 98602
# Upserted item with id 98603
# Upserted item with id 98604
# Upserted item with id 98605
# Upserted item with id 98606
# Upserted item with id 98607
# Upserted item with id 98608
# Upserted item with id 98609
# Upserted item with id 98610
# Upserted item with id 98611
# Upserted item with id 98612
# Upserted item with id 98613
# Upserted item with id 98614
# Upserted item with id 98615
# Upserted item with id 98616
# Upserted item with id 98617
# Upserted item with id 98618
# Upserted item with id 98619
# Upserted item with id 98620
# Upserted item with id 98621
# Upserted item with id 98622
# Upserted item with id 98623
# Upserted item with id 98624
# Upserted item with id 98625
# Upserted item with id 98626
# Upserted item with id 98627
# Upserted item with id 98628
# Upserted item with id 98629
# Upserted item with id 98630
# Upserted item with id 98631
# Upserted item with id 98632
# Upserted item with id 98633
# Upserted item with id 98634
# Upserted item with id 98635
# Upserted item with id 98636
# Upserted item with id 98637
# Upserted item with id 98638
# Upserted item with id 98639
# Upserted item with id 98640
# Upserted item with id 98641
# Upserted item with id 98642
# Upserted item with id 98643
# Upserted item with id 98644
# Upserted item with id 98645
# Upserted item with id 98646
# Upserted item with id 98647
# Upserted item with id 98648
# Upserted item with id 98649
# Upserted item with id 98650
# Upserted item with id 98651
# Upserted item with id 98652
# Upserted item with id 98653
# Upserted item with id 98654
# Upserted item with id 98655
# Upserted item with id 98656
# Upserted item with id 98657
# Upserted item with id 98658
# Upserted item with id 98659
# Upserted item with id 98660
# Upserted item with id 98661
# Upserted item with id 98662
# Upserted item with id 98663
# Upserted item with id 98664
# Upserted item with id 98665
# Upserted item with id 98666
# Upserted item with id 98667
# Upserted item with id 98668
# Upserted item with id 98669
# Upserted item with id 98670
# Upserted item with id 98671
# Upserted item with id 98672
# Upserted item with id 98673
# Upserted item with id 98674
# Upserted item with id 98675
# Upserted item with id 98676
# Upserted item with id 98677
# Upserted item with id 98678
# Upserted item with id 98679
# Upserted item with id 98680
# Upserted item with id 98681
# Upserted item with id 98682
# Upserted item with id 98683
# Upserted item with id 98684
# Upserted item with id 98685
# Upserted item with id 98686
# Upserted item with id 98687
# Upserted item with id 98688
# Upserted item with id 98689
# Upserted item with id 98690
# Upserted item with id 98691
# Upserted item with id 98692
# Upserted item with id 98693
# Upserted item with id 98694
# Upserted item with id 98695
# Upserted item with id 98696
# Upserted item with id 98697
# Upserted item with id 98698
# Upserted item with id 98699
# Upserted item with id 98700
# Upserted item with id 98701
# Upserted item with id 98702
# Upserted item with id 98703
# Upserted item with id 98704
# Upserted item with id 98705
# Upserted item with id 98706
# Upserted item with id 98707
# Upserted item with id 98708
# Upserted item with id 98709
# Upserted item with id 98710
# Upserted item with id 98711
# Upserted item with id 98712
# Upserted item with id 98713
# Upserted item with id 98714
# Upserted item with id 98715
# Upserted item with id 98716
# Upserted item with id 98717
# Upserted item with id 98718
# Upserted item with id 98719
# Upserted item with id 98720
# Upserted item with id 98721
# Upserted item with id 98722
# Upserted item with id 98723
# Upserted item with id 98724
# Upserted item with id 98725
# Upserted item with id 98726
# Upserted item with id 98727
# Upserted item with id 98728
# Upserted item with id 98729
# Upserted item with id 98730
# Upserted item with id 98731
# Upserted item with id 98732
# Upserted item with id 98733
# Upserted item with id 98734
# Upserted item with id 98735
# Upserted item with id 98736
# Upserted item with id 98737
# Upserted item with id 98738
# Upserted item with id 98739
# Upserted item with id 98740
# Upserted item with id 98741
# Upserted item with id 98742
# Upserted item with id 98743
# Upserted item with id 98744
# Upserted item with id 98745
# Upserted item with id 98746
# Upserted item with id 98747
# Upserted item with id 98748
# Upserted item with id 98749
# Upserted item with id 98750
# Upserted item with id 98751
# Upserted item with id 98752
# Upserted item with id 98753
# Upserted item with id 98754
# Upserted item with id 98755
# Upserted item with id 98756
# Upserted item with id 98757
# Upserted item with id 98758
# Upserted item with id 98759
# Upserted item with id 98760
# Upserted item with id 98761
# Upserted item with id 98762
# Upserted item with id 98763
# Upserted item with id 98764
# Upserted item with id 98765
# Upserted item with id 98766
# Upserted item with id 98767
# Upserted item with id 98768
# Upserted item with id 98769
# Upserted item with id 98770
# Upserted item with id 98771
# Upserted item with id 98772
# Upserted item with id 98773
# Upserted item with id 98774
# Upserted item with id 98775
# Upserted item with id 98776
# Upserted item with id 98777
# Upserted item with id 98778
# Upserted item with id 98779
# Upserted item with id 98780
# Upserted item with id 98781
# Upserted item with id 98782
# Upserted item with id 98783
# Upserted item with id 98784
# Upserted item with id 98785
# Upserted item with id 98786
# Upserted item with id 98787
# Upserted item with id 98788
# Upserted item with id 98789
# Upserted item with id 98790
# Upserted item with id 98791
# Upserted item with id 98792
# Upserted item with id 98793
# Upserted item with id 98794
# Upserted item with id 98795
# Upserted item with id 98796
# Upserted item with id 98797
# Upserted item with id 98798
# Upserted item with id 98799
# Upserted item with id 98800
# Upserted item with id 98801
# Upserted item with id 98802
# Upserted item with id 98803
# Upserted item with id 98804
# Upserted item with id 98805
# Upserted item with id 98806
# Upserted item with id 98807
# Upserted item with id 98808
# Upserted item with id 98809
# Upserted item with id 98810
# Upserted item with id 98811
# Upserted item with id 98812
# Upserted item with id 98813
# Upserted item with id 98814
# Upserted item with id 98815
# Upserted item with id 98816
# Upserted item with id 98817
# Upserted item with id 98818
# Upserted item with id 98819
# Upserted item with id 98820
# Upserted item with id 98821
# Upserted item with id 98822
# Upserted item with id 98823
# Upserted item with id 98824
# Upserted item with id 98825
# Upserted item with id 98826
# Upserted item with id 98827
# Upserted item with id 98828
# Upserted item with id 98829
# Upserted item with id 98830
# Upserted item with id 98831
# Upserted item with id 98832
# Upserted item with id 98833
# Upserted item with id 98834
# Upserted item with id 98835
# Upserted item with id 98836
# Upserted item with id 98837
# Upserted item with id 98838
# Upserted item with id 98839
# Upserted item with id 98840
# Upserted item with id 98841
# Upserted item with id 98842
# Upserted item with id 98843
# Upserted item with id 98844
# Upserted item with id 98845
# Upserted item with id 98846
# Upserted item with id 98847
# Upserted item with id 98848
# Upserted item with id 98849
# Upserted item with id 98850
# Upserted item with id 98851
# Upserted item with id 98852
# Upserted item with id 98853
# Upserted item with id 98854
# Upserted item with id 98855
# Upserted item with id 98856
# Upserted item with id 98857
# Upserted item with id 98858
# Upserted item with id 98859
# Upserted item with id 98860
# Upserted item with id 98861
# Upserted item with id 98862
# Upserted item with id 98863
# Upserted item with id 98864
# Upserted item with id 98865
# Upserted item with id 98866
# Upserted item with id 98867
# Upserted item with id 98868
# Upserted item with id 98869
# Upserted item with id 98870
# Upserted item with id 98871
# Upserted item with id 98872
# Upserted item with id 98873
# Upserted item with id 98874
# Upserted item with id 98875
# Upserted item with id 98876
# Upserted item with id 98877
# Upserted item with id 98878
# Upserted item with id 98879
# Upserted item with id 98880
# Upserted item with id 98881
# Upserted item with id 98882
# Upserted item with id 98883
# Upserted item with id 98884
# Upserted item with id 98885
# Upserted item with id 98886
# Upserted item with id 98887
# Upserted item with id 98888
# Upserted item with id 98889
# Upserted item with id 98890
# Upserted item with id 98891
# Upserted item with id 98892
# Upserted item with id 98893
# Upserted item with id 98894
# Upserted item with id 98895
# Upserted item with id 98896
# Upserted item with id 98897
# Upserted item with id 98898
# Upserted item with id 98899
# Upserted item with id 98900
# Upserted item with id 98901
# Upserted item with id 98902
# Upserted item with id 98903
# Upserted item with id 98904
# Upserted item with id 98905
# Upserted item with id 98906
# Upserted item with id 98907
# Upserted item with id 98908
# Upserted item with id 98909
# Upserted item with id 98910
# Upserted item with id 98911
# Upserted item with id 98912
# Upserted item with id 98913
# Upserted item with id 98914
# Upserted item with id 98915
# Upserted item with id 98916
# Upserted item with id 98917
# Upserted item with id 98918
# Upserted item with id 98919
# Upserted item with id 98920
# Upserted item with id 98921
# Upserted item with id 98922
# Upserted item with id 98923
# Upserted item with id 98924
# Upserted item with id 98925
# Upserted item with id 98926
# Upserted item with id 98927
# Upserted item with id 98928
# Upserted item with id 98929
# Upserted item with id 98930
# Upserted item with id 98931
# Upserted item with id 98932
# Upserted item with id 98933
# Upserted item with id 98934
# Upserted item with id 98935
# Upserted item with id 98936
# Upserted item with id 98937
# Upserted item with id 98938
# Upserted item with id 98939
# Upserted item with id 98940
# Upserted item with id 98941
# Upserted item with id 98942
# Upserted item with id 98943
# Upserted item with id 98944
# Upserted item with id 98945
# Upserted item with id 98946
# Upserted item with id 98947
# Upserted item with id 98948
# Upserted item with id 98949
# Upserted item with id 98950
# Upserted item with id 98951
# Upserted item with id 98952
# Upserted item with id 98953
# Upserted item with id 98954
# Upserted item with id 98955
# Upserted item with id 98956
# Upserted item with id 98957
# Upserted item with id 98958
# Upserted item with id 98959
# Upserted item with id 98960
# Upserted item with id 98961
# Upserted item with id 98962
# Upserted item with id 98963
# Upserted item with id 98964
# Upserted item with id 98965
# Upserted item with id 98966
# Upserted item with id 98967
# Upserted item with id 98968
# Upserted item with id 98969
# Upserted item with id 98970
# Upserted item with id 98971
# Upserted item with id 98972
# Upserted item with id 98973
# Upserted item with id 98974
# Upserted item with id 98975
# Upserted item with id 98976
# Upserted item with id 98977
# Upserted item with id 98978
# Upserted item with id 98979
# Upserted item with id 98980
# Upserted item with id 98981
# Upserted item with id 98982
# Upserted item with id 98983
# Upserted item with id 98984
# Upserted item with id 98985
# Upserted item with id 98986
# Upserted item with id 98987
# Upserted item with id 98988
# Upserted item with id 98989
# Upserted item with id 98990
# Upserted item with id 98991
# Upserted item with id 98992
# Upserted item with id 98993
# Upserted item with id 98994
# Upserted item with id 98995
# Upserted item with id 98996
# Upserted item with id 98997
# Upserted item with id 98998
# Upserted item with id 98999
# Upserted item with id 99000
# Finished upserting users

# %%
# Get items from container to validate they were inserted
print('Get all items in container')
items = list(container.read_all_items(max_item_count=10))
print(items)
# Out:
# Get all items in container
# [{'id': '97001', 'name': 'sasasa', 'mail': 'sasha_m3x@mail.ru', 'birth': '1973-09-21', 'gender': 'Female', 'orientation': ' 1', 'p_orientation': '2', 'city': 'Елин Пелин', 'area': 'София', 'country': 'България', 'photo_id': '1010000', 'visible': 'Y', '_rid': 'l6J7AMEWHXcBAAAAAAAAAA==', '_self': 'dbs/l6J7AA==/colls/l6J7AMEWHXc=/docs/l6J7AMEWHXcBAAAAAAAAAA==/', '_etag': '"ee01593e-0000-1800-0000-675d6a550000"', '_attachments': 'attachments/', '_ts': 1734175317}, {'id': '97002', 'name': 'faith221', 'mail': 'badgel@millfield.somerset.sch.uk', 'birth': '1986-08-19', 'gender': 'Female', 'orientation': ' 2', 'p_orientation': '1', 'city': 'Искър', 'area': 'Плевен', 'country': 'България', 'photo_id': '1010001', 'visible': 'Y', '_rid': 'l6J7AMEWHXcCAAAAAAAAAA==', '_self': 'dbs/l6J7AA==/colls/l6J7AMEWHXc=/docs/l6J7AMEWHXcCAAAAAAAAAA==/', '_etag': '"ee015b3e-0000-1800-0000-675d6a550000"', '_attachments': 'attachments/', '_ts': 1734175317}, {'id': '97003', 'name': 'Vyacheslav141138', 'mail': 'suckmyrocket@bigmir.net', 'birth': '1985-08-07', 'gender': 'Female', 'orientation': ' 1', 'p_orientation': '2', 'city': 'Брезово', 'area': 'Пловдив', 'country': 'България', 'photo_id': '1010002', 'visible': 'Y', '_rid': 'l6J7AMEWHXcDAAAAAAAAAA==', '_self': 'dbs/l6J7AA==/colls/l6J7AMEWHXc=/docs/l6J7AMEWHXcDAAAAAAAAAA==/', '_etag': '"ee015d3e-0000-1800-0000-675d6a550000"', '_attachments': 'attachments/', '_ts': 1734175317}, {'id': '97004', 'name': 'Ramos20', 'mail': 'ramoswilliamson@yahoo.com', 'birth': '1960-08-10', 'gender': 'Female', 'orientation': ' 1', 'p_orientation': '2', 'city': 'Божурище', 'area': 'София', 'country': 'България', 'photo_id': '1010003', 'visible': 'Y', '_rid': 'l6J7AMEWHXcEAAAAAAAAAA==', '_self': 'dbs/l6J7AA==/colls/l6J7AMEWHXc=/docs/l6J7AMEWHXcEAAAAAAAAAA==/', '_etag': '"ee015e3e-0000-1800-0000-675d6a550000"', '_attachments': 'attachments/', '_ts': 1734175317}, {'id': '97005', 'name': 'olivertvist', 'mail': 'olivertvist66@mail.ru', 'birth': '1966-12-31', 'gender': 'Female', 'orientation': ' 1', 'p_orientation': '2', 'city': 'Полски Тръмбеш', 'area': 'Велико Търново', 'country': 'България', 'photo_id': '1010009', 'visible': 'Y', '_rid': 'l6J7AMEWHXcFAAAAAAAAAA==', '_self': 'dbs/l6J7AA==/colls/l6J7AMEWHXc=/docs/l6J7AMEWHXcFAAAAAAAAAA==/', '_etag': '"ee01613e-0000-1800-0000-675d6a550000"', '_attachments': 'attachments/', '_ts': 1734175317}, {'id': '97006', 'name': 'filix', 'mail': 'rysan.f@seznam.cz', 'birth': '1982-05-27', 'gender': 'Female', 'orientation': ' 1', 'p_orientation': '2', 'city': 'Минерални бани', 'area': 'Хасково', 'country': 'България', 'photo_id': '1010010', 'visible': 'Y', '_rid': 'l6J7AMEWHXcGAAAAAAAAAA==', '_self': 'dbs/l6J7AA==/colls/l6J7AMEWHXc=/docs/l6J7AMEWHXcGAAAAAAAAAA==/', '_etag': '"ee01623e-0000-1800-0000-675d6a560000"', '_attachments': 'attachments/', '_ts': 1734175318}, {'id': '97007', 'name': 'lapokiny', 'mail': 'ladylapokiny@yahoo.com', 'birth': '1984-08-11', 'gender': 'Female', 'orientation': ' 2', 'p_orientation': '1', 'city': 'Опака', 'area': 'Търговище', 'country': 'България', 'photo_id': '1010016', 'visible': 'Y', '_rid': 'l6J7AMEWHXcHAAAAAAAAAA==', '_self': 'dbs/l6J7AA==/colls/l6J7AMEWHXc=/docs/l6J7AMEWHXcHAAAAAAAAAA==/', '_etag': '"ee01633e-0000-1800-0000-675d6a560000"', '_attachments': 'attachments/', '_ts': 1734175318}, {'id': '97008', 'name': 'kaybee123456', 'mail': 'charlessykes22@hotmail.com', 'birth': '1953-05-13', 'gender': 'Female', 'orientation': ' 1', 'p_orientation': '2', 'city': 'Дряново', 'area': 'Габрово', 'country': 'България', 'photo_id': '1010017', 'visible': 'Y', '_rid': 'l6J7AMEWHXcIAAAAAAAAAA==', '_self': 'dbs/l6J7AA==/colls/l6J7AMEWHXc=/docs/l6J7AMEWHXcIAAAAAAAAAA==/', '_etag': '"ee01643e-0000-1800-0000-675d6a560000"', '_attachments': 'attachments/', '_ts': 1734175318}, {'id': '97009', 'name': '68vindiesel', 'mail': 'tymeetimartimia@yahoo.com', 'birth': '1961-11-19', 'gender': 'Female', 'orientation': ' 1', 'p_orientation': '2', 'city': 'Завет', 'area': 'Разград', 'countr ...
